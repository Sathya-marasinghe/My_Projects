# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathya-marasinghe/My_Projects/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My first ML project - IRIS
#
#
#   ### 01. Import Libaries

# %%
# !pip install opendatasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import opendatasets as od

# %% [markdown]
#   ### 01. Import Dataset

# %%
od.download("https://www.kaggle.com/datasets/himanshunakrani/iris-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sathyamarasinghe
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 0.98k/0.98k [00:00<00:00, 355kB/s]

# %%
data = pd.read_csv("/content/iris-dataset/iris.csv")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
x = data.drop('species', axis=1)
y = data['species']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)
x = x[0:5]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
plt.scatter(data.petal_length,data.species)

# %%
plt.scatter(data.petal_width,data.species)

# %%
# !pip install scikit-learn
from sklearn.svm import SVC
model = SVC(kernel = 'poly')
model.fit(x_train,y_train)
# Out:
# ...
# SVC(kernel='poly')

# %%
pred = model.predict(x_test)
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 32            5.2          4.1           1.5          0.1
# 91            6.1          3.0           4.6          1.4
# 52            6.9          3.1           4.9          1.5
# 111           6.4          2.7           5.3          1.9
# 139           6.9          3.1           5.4          2.1
# 27            5.2          3.5           1.5          0.2
# 135           7.7          3.0           6.1          2.3
# 93            5.0          2.3           3.3          1.0
# 119           6.0          2.2           5.0          1.5
# 58            6.6          2.9           4.6          1.3
# 12            4.8          3.0           1.4          0.1
# 36            5.5          3.5           1.3          0.2
# 56            6.3          3.3           4.7          1.6
# 28            5.2          3.4           1.4          0.2
# 118           7.7          2.6           6.9          2.3
# ...

# %%
y_test
# Out:
# 32         setosa
# 91     versicolor
# 52     versicolor
# 111     virginica
# 139     virginica
# 27         setosa
# 135     virginica
# 93     versicolor
# 119     virginica
# 58     versicolor
# 12         setosa
# 36         setosa
# 56     versicolor
# 28         setosa
# 118     virginica
# 20         setosa
# 2          setosa
# 46         setosa
# 142     virginica
# 4          setosa
# 26         setosa
# 143     virginica
# 116     virginica
# 18         setosa
# 9          setosa
# 48         setosa
# 11         setosa
# 51     versicolor
# 147     virginica
# 86     versicolor
# Name: species, dtype: object

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, pred)
print(accuracy)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,pred)
cm
# Out:
# array([[14,  0,  0],
#        [ 0,  7,  0],
#        [ 0,  0,  9]])

# %%
result = pd.DataFrame(data= [y_test,pred],index= ["y_test","pred"])
result.T
