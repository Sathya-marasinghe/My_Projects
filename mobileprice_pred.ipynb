# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathya-marasinghe/My_Projects/blob/main/mobileprice_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Import Data Set**

# %%
df = pd.read_csv("/Mobile_Price_Classification-220531-204702.csv",encoding="latin-1")

# %%
df.head
# Out:
# <bound method NDFrame.head of       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
x = df.iloc[:,0:20]
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
x = df.drop('price_range', axis = 1)
y = df['price_range']

# %%
y = df['price_range']
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    1
# 1998    0
# 1999    1
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train ,y_test = train_test_split(x,y,test_size=0.25)

# %%
x_test.shape
x_test
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1271           1944     1          1.8         1   0       1          31
# 1662           1751     0          2.5         0   1       0           4
# 1898            684     1          0.9         1   3       1          63
# 1816            584     1          1.7         1   1       1          19
# 1572            895     0          0.5         1   6       0          16
# ...             ...   ...          ...       ...  ..     ...         ...
# 739            1303     0          1.0         1   0       1          15
# 494            1225     1          2.4         0   0       0          15
# 519            1928     1          1.8         0   9       1          19
# 823            1593     1          1.0         0   0       1          52
# 1443           1180     1          2.5         0   0       1          27
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
x_train.shape
# Out:
# (1500, 20)

# %%
y_train
# Out:
# 1640    0
# 1695    0
# 714     1
# 99      1
# 1735    1
#        ..
# 1041    1
# 976     1
# 244     1
# 48      0
# 1918    0
# Name: price_range, Length: 1500, dtype: int64

# %% [markdown]
# **ANN MODEL**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
num_features = 20
num_classes = 1

# %%
model = Sequential()
model.add(Dense(8, input_dim=num_features, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(num_classes, activation='sigmoid'))

# %% [markdown]
# **Complie the Model**

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 8)                 168
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 1)                 5
#
# ...
# Total params: 209 (836.00 Byte)
# Trainable params: 209 (836.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Fit, train the model for 100 epoch with batch size of 32**

# %%
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 3s 3ms/step - loss: 9.5441 - accuracy: 0.4747
# Epoch 2/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7665 - accuracy: 0.5013
# Epoch 3/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7233 - accuracy: 0.5047
# Epoch 4/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7129 - accuracy: 0.5067
# Epoch 5/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7078 - accuracy: 0.5067
# Epoch 6/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7039 - accuracy: 0.5073
# Epoch 7/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7012 - accuracy: 0.5073
# Epoch 8/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6996 - accuracy: 0.5080
# Epoch 9/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6985 - accuracy: 0.5080
# Epoch 10/100
# ...

# %%
model.save_weights('model_mobileprice_pred.h5')

# %%
model.load_weights('model_mobileprice_pred.h5')
